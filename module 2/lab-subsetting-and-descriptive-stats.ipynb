# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
fig, [Slava,ax2]=plt.subplots(1,2)

Slava.set_title('Plotting (x-y)')
Slava.plot(x,y, label='linear')
Slava.set_xlabel('x label')
Slava.set_ylabel('y label')

ax2.set_title('Plotting (x-z)')
ax2.plot(x,z, label='quadratic')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')


plt.show()

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
plt.plot(x,y, label='linear')
plt.plot(x,z, label='quadratic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title('Plotting (x-y) & (x-z)')
plt.legend()
plt.show()

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig, [Slava,ax2]=plt.subplots(1,2,figsize=(15,6))

Slava.set_title('Plotting (x-y)')
Slava.plot(x,y, label='linear')
Slava.set_xlabel('x label')
Slava.set_ylabel('y label')

ax2.set_title('Plotting (x-z)')
ax2.plot(x,z, label='quadratic')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')


plt.show()

# %%
# ?plt.figure
# Out:
# Signature:
# plt.figure(
#     num=None,
#     figsize=None,
#     dpi=None,
#     facecolor=None,
#     edgecolor=None,
#     frameon=True,
#     FigureClass=<class 'matplotlib.figure.Figure'>,
#     clear=False,
#     **kwargs,
# )
# Docstring:
# Create a new figure.
#
# Parameters
# ----------
#
# num : integer or string, optional, default: None
#     If not provided, a new figure will be created, and the figure number
#     will be incremented. The figure objects holds this number in a `number`
#     attribute.
#     If num is provided, and a figure with this id already exists, make
#     it active, and returns a reference to it. If this figure does not
#     exists, create it and returns it.
#     If num is a string, the window title will be set to this figure's
#     `num`.
#
# figsize : (float, float), optional, default: None
#     width, height in inches. If not provided, defaults to
#     :rc:`figure.figsize` = ``[6.4, 4.8]``.
#
# dpi : integer, optional, default: None
#     resolution of the figure. If not provided, defaults to
#     :rc:`figure.dpi` = ``100``.
#
# facecolor :
#     the background color. If not provided, defaults to
#     :rc:`figure.facecolor` = ``'w'``.
#
# edgecolor :
#     the border color. If not provided, defaults to
#     :rc:`figure.edgecolor` = ``'w'``.
#
# frameon : bool, optional, default: True
#     If False, suppress drawing the figure frame.
#
# FigureClass : subclass of `~matplotlib.figure.Figure`
#     Optionally use a custom `.Figure` instance.
#
# clear : bool, optional, default: False
#     If True and the figure already exists, then it is cleared.
#
# Returns
# -------
# figure : `~matplotlib.figure.Figure`
#     The `.Figure` instance returned will also be passed to new_figure_manager
#     in the backends, which allows to hook custom `.Figure` classes into the
#     pyplot interface. Additional kwargs will be passed to the `.Figure`
#     init function.
#
# Notes
# -----
# If you are creating many figures, make sure you explicitly call
# :func:`.pyplot.close` on the figures you are not using, because this will
# enable pyplot to properly clean up the memory.
#
# `~matplotlib.rcParams` defines the default values, which can be modified
# in the matplotlibrc file.
# File:      c:\users\tirado\appdata\local\continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py
# Type:      function

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
#alredy done

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
# your code here
y1=x**2
y2=np.exp(x)

fig, [Slava,R]=plt.subplots(1,2,figsize=(15,6))

Slava.set_title('Plotting (x-y)')
Slava.plot(x,y1, label='linear')
Slava.set_xlabel('x label')
Slava.set_ylabel('y label')


R.set_title('Plotting (x-z)')
R.plot(x,y2, label='quadratic')
R.set_xlabel('x label')
R.set_ylabel('y label')
R.set_xscale("log")


plt.show()

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df=pd.read_csv('vehicles.csv')

# %%
sns.scatterplot(data=df,x='Combined MPG',y='Highway MPG')

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here

# %%
bx=sns.boxplot(df['Combined MPG'])
plt.show(x)

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
sns.set(style="darkgrid")
y=sns.distplot(df['Fuel Barrels/Year'],kde=False,color="m")

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
sns.barplot(x='Fuel Type ',y='City MPG',data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-f95df1425be3> in <module>
#       1 # your code here
# ----> 2 sns.barplot(x='Fuel Type ',y='City MPG',data=df)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Fuel Type '
